# %%
import pandas as pd
import numpy as np
df = pd.read_csv('E:\\Third Year Engineering (TE-2019)\\Semester - 6\\LP2\\Programs - AI\\Assignment 6\\archive (2)\\diagnosis.csv', names=['Temperature',
'decimal','Nausea','pain', 'Urine Pushing','Micturition pains', 'Burning of urethra','d1', 'd2'])


df['Temperature'] = df['Temperature']+(int(0.1)*df['decimal'])
df.drop(['decimal'],axis=1,inplace=True)
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                      Temperature  \
# id       diagnosis radius_mean texture_mean perimeter_mean area_mean smoothness_mean compactness_mean concavity_mean concave points_mean symmetry_mean fractal_dimension_mean radius_se texture_se perimeter_se area_se smoothness_se compactness_se concavity_se concave points_se symmetry_se fractal_dimension_se radius_worst texture_worst  perimeter_worst
# ...

# %%
df.replace(['no','yes'],[0,1], inplace=True)

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
model = tf.keras.models.Sequential([
tf.keras.layers.Input(shape=(6,)),
tf.keras.layers.Dense(32,activation='sigmoid'),
tf.keras.layers.Dense(128,activation='sigmoid'),
tf.keras.layers.Dense(32,activation='sigmoid'),
tf.keras.layers.Dropout(0.1),
tf.keras.layers.Dense(2,activation='sigmoid')
])

# %%
model.compile(optimizer='adam',loss=tf.keras.losses.BinaryCrossentropy(),metrics=[tf.keras.metrics.BinaryAccuracy()])

# %%
X = df[['Temperature','Nausea','pain','Urine Pushing','Micturition pains','Burning of urethra',]]
# X = np.asarray(X).astype('float32')
y = df[['d1','d2']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 32)                224
#
#  dense_1 (Dense)             (None, 128)               4224
#
#  dense_2 (Dense)             (None, 32)                4128
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_3 (Dense)             (None, 2)                 66
#
# ...
# Total params: 8,642
# Trainable params: 8,642
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,epochs=150)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# e:\Third Year Engineering (TE-2019)\Semester - 6\LP2\Programs - AI\Assignment 6\file.ipynb Cell 9' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/Third%20Year%20Engineering%20%28TE-2019%29/Semester%20-%206/LP2/Programs%20-%20AI/Assignment%206/file.ipynb#ch0000008?line=0'>1</a> model.fit(X_train,y_train,epochs=150)
#
# File c:\Python310\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///c%3A/Python310/lib/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///c%3A/Python310/lib/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
# ...
